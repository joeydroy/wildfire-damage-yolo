# %% [markdown]
# <a href="https://colab.research.google.com/github/joeydroy/wildfire-damage-yolo/blob/main/02__DatasetPipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install Libraries
# !pip install rasterio --quiet

# %%
#Import Libraries
import os
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #Load Sentinel-2 Exports into Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/MyDrive/SIA_FinalProject/FireImagery"
print(os.listdir(path))
# Out:
# ['CAMP_FIRE_PREFIRE_SENTINEL2.tif', 'MARSHALL_FIRE_PREFIRE_SENTINEL2.tif', 'MAUI_FIRE_PREFIRE_SENTINEL2.tif', 'MAUI_FIRE_POSTFIRE_SENTINEL2.tif', 'CAMP_FIRE_POSTFIRE_SENTINEL2.tif', 'MARSHALL_FIRE_POSTFIRE_SENTINEL2.tif']

# %%
file = "/content/drive/MyDrive/SIA_FinalProject/FireImagery/CAMP_FIRE_POSTFIRE_SENTINEL2.tif"

img = rasterio.open(file)
array = img.read()

print(array.shape)
# Out:
# (8, 2785, 3340)

# %% [markdown]
# #Convert Images to Training Patches

# %% [markdown]
# #Assign Labels

# %% [markdown]
# #Train and Compare Models
